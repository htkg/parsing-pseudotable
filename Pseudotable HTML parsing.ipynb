# %%
from bs4 import BeautifulSoup
import lxml
import re
import pandas as pd

# %%
r = re.compile(r'R(\d+)C(\d+)')

def make_soup(path):
    with open(path, encoding='utf-8') as f:
        raw_html = f.read()
        f.close()
        soup = BeautifulSoup(raw_html, 'lxml')
        return soup

def save_pkl(df, name='df.pkl'):
    df.to_pickle(name)

def create_df(rows, columns, index='№ п/п'):
    adm_df = pd.DataFrame(rows, columns=columns).set_index(index)
    return adm_df

def parse_data(soup, cid: str) -> list:
    results = []

    found = soup.find(cid=cid).previous_sibling
    for sib in list(found.next_siblings):
        if sib.string == '\n':
            continue
        location = sib.attrs.get('cid')
        contents = sib.string

        if contents is None:
            contents = [desc.string for desc in sib.descendants]
            contents = [item.string.rstrip() for item in contents if item is not None]
            # This block avoids cases for "contents = []", makes pandas pretty
            if len(contents) == 0:
                contents = ''
        results.append((str(location), str(contents)))

    return results

def make_rows(extracted_data: list, num_cols: int) -> list:
    results = []
    for row in range(0, len(extracted_data), num_cols):
        each_row_list = extracted_data[row:row + num_cols]
        each_row_data = [data[1] for data in each_row_list]
        # Avoids a case where the last row is (usually) empty
        if each_row_data and len(each_row_data[0]) > 0:
            results.append(each_row_data)

    return results

def make_columns(soup):
    ''' Analogue search for columns '''
    max_column = max(int(r.search(div['cid']).group(2)) for div in soup.find_all(cid=r))
    temp_labels = []
    for i in range(1, max_column + 1):
        if not soup.find(cid='R{}C{}'.format(7, i)) is None:
            temp_labels.append(soup.find(cid='R{}C{}'.format(7, i)).div.text)
    for i in temp_labels:
      if i not in temp_labels:
        temp_labels.append(i)
            
    print(temp_labels)
    return temp_labels

# %%
FILE_PATH = 'Программа двух дипломов НИУ ВШЭ и Университета Кёнхи Экономика и политика в Азии.html'

# %%
soup = make_soup(FILE_PATH)

# %%
columns_plus = parse_data(soup, cid="R7C1")
data = make_rows(columns_plus, num_cols=44)
cols = data[0]
del data[0]
rows = data

# %%
df = create_df(rows, cols)
df
# Out:
#       Регистрационный номер          Фамилия, имя, отчество  \
# № п/п
# 1                      6437     Абрамова Софья Владимировна
# 2                      1279    Агаркова Мария Александровна
# 3                     13467        Азаров Георгий Сергеевич
# 4                      7326   Алексеев Александр Дмитриевич
# 5                      4596   Андрусенко Софья Владимировна
# ...                     ...                             ...
# 183                    7765  Шуленина Александра Васильевна
# 184                    2464   Шурховецкая Людмила Рубеновна
# 185                   18372     Эрендженова Даяна Батыровна
# 186                   14786         Юрченко Дана Витальевна
# 187                    1920         Янкович Дарья Антоновна
#
#       Подлинник/Копия документа \nоб образовании Медаль / диплом с отличием  \
# № п/п
# 1                                          Копия                          +
# 2                                          Копия                          +
# 3                                          Копия                          -
# 4                                      Подлинник                          +
# 5                                          Копия                          -
# ...                                          ...                        ...
# 183                                    Подлинник                          -
# 184                                        Копия                          -
# 185                                    Подлинник                          +
# 186                                        Копия                          -
# 187                                    Подлинник                          -
#
#       Право поступления без вступительных испытаний  \
# № п/п
# 1
# 2
# 3
# 4
# 5
# ...                                             ...
# 183
# 184
# 185
# 186
# 187
#
#       Поступление на места в рамках квоты \nдля лиц, имеющих особое право  \
# № п/п
# 1                                                      -
# 2                                                      -
# 3                                                      -
# 4                                                      -
# 5                                                      -
# ...                                                  ...
# 183                                                    -
# 184                                                    -
# 185                                                    -
# 186                                                    -
# 187                                                    -
#
#       Поступление на места в рамках квоты\nцелевого приема  \
# № п/п
# 1                                                      -
# 2                                                      -
# 3                                                      -
# 4                                                      -
# 5                                                      -
# ...                                                  ...
# 183                                                    -
# 184                                                    -
# 185                                                    -
# 186                                                    -
# 187                                                    -
#
#       Наличие согласия на зачисление Дата и время предоставления согласия  \
# № п/п
# 1                                Нет
# 2                                Нет
# 3                                Нет
# 4                                 Да                      03.08.2020 0:00
# 5                                Нет
# ...                              ...                                  ...
# 183                               Да                      03.08.2020 0:00
# 184                              Нет
# 185                               Да                     12.08.2020 11:37
# 186                              Нет
# 187                               Да                     11.08.2020 22:37
#
#       История  ...      Все выбранные конкурсы Олимпиады Приказ о зачислении  \
# № п/п          ...
# 1          98  ...  МО_Л, ЭКПА, Ант (Ист), ИСТ
# 2          54  ...                  Вост, ЭКПА
# 3          58  ...                  Вост, ЭКПА
# 4          94  ...          Вост, ЭКПА (подл.)
# 5              ...           ПРАД, ЭКПА, МИРЭК
# ...       ...  ...                         ...       ...                 ...
# 183        68  ...    Вост, ЭКПА (подл.), МО_Л
# 184        83  ...            Вост, МО_Л, ЭКПА
# 185        92  ...          ЭКПА (подл.), Вост
# 186        75  ...                  МО_Л, ЭКПА
# 187        81  ...          ЭКПА (подл.), Вост
#
#       Основание зачисления / выбытия Последний результат опроса  \
# № п/п
# 1
# 2
# 3
# 4
# 5
# ...                              ...                        ...
# 183
# 184
# 185
# 186
# 187
#
#       Статус соотечественника Гражданство Гражданство СНГ  \
# № п/п
# 1        Российская Федерация                          Да
# 2        Российская Федерация                          Да
# 3        Российская Федерация                          Да
# 4        Российская Федерация                          Да
# 5        Российская Федерация                          Да
# ...                       ...         ...             ...
# 183      Российская Федерация                          Да
# 184      Российская Федерация                          Да
# 185      Российская Федерация                          Да
# 186      Российская Федерация                          Да
# 187      Российская Федерация                          Да
#
#       Имеется легализация / Имеется \nпризнание Второй иностранный язык
# № п/п
# 1                                       Нет/Нет
# 2                                       Нет/Нет
# 3                                       Нет/Нет
# 4                                       Нет/Нет
# 5                                       Нет/Нет
# ...                                         ...                     ...
# 183                                     Нет/Нет
# 184                                     Нет/Нет
# 185                                     Нет/Нет
# 186                                     Нет/Нет
# 187                                     Нет/Нет
#
# [187 rows x 43 columns]
